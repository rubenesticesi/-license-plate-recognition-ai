# %% [markdown]
# # FASE 4: Preparación del dataset\nVerificamos la estructura y creamos `data.yaml` para YOLOv8.\n

# %%
import yaml\nimport os\n\ndata_yaml_path = '../data/raw/data.yaml'\n\ndata_config = {\n    'path': os.path.abspath('../data/raw'),\n    'train': 'train/images',\n    'val': 'valid/images',\n    'test': 'test/images',\n    'names': {0: 'license_plate'}\n}\n\nwith open(data_yaml_path, 'w') as f:\n    yaml.dump(data_config, f, default_flow_style=False)\n\nprint(f'Archivo creado en: {data_yaml_path}')\n
